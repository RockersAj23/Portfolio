# %%
import pandas as pd
import numpy as np

# %%
train_data=pd.read_csv(r"C:\Users\Ajay Mulgir\portfolio project\Portfolio\GUWAHATI\WEEK5\Train_Data.csv")
test_data=pd.read_csv(r"C:\Users\Ajay Mulgir\portfolio project\Portfolio\GUWAHATI\WEEK5\Test_Data.csv")
Sample_Submission=pd.read_csv(r"C:\Users\Ajay Mulgir\portfolio project\Portfolio\GUWAHATI\WEEK5\Sample_Submission.csv")

# %%
train_data.head()
# Out:
#    duration protocoltype      service flag  srcbytes  dstbytes  land  \
# 0         0          tcp  netbios_dgm  REJ         0         0     0
# 1         0          tcp         smtp   SF      1239       400     0
# 2         0          tcp         http   SF       222       945     0
# 3         0          tcp         http   SF       235      1380     0
# 4         0          tcp    uucp_path  REJ         0         0     0
#
#    wrongfragment  urgent  hot  ...  dsthostsamesrvrate  dsthostdiffsrvrate  \
# 0              0       0    0  ...                0.06                0.06
# 1              0       0    0  ...                0.45                0.04
# 2              0       0    0  ...                1.00                0.00
# 3              0       0    0  ...                1.00                0.00
# 4              0       0    0  ...                0.01                0.08
#
#    dsthostsamesrcportrate  dsthostsrvdiffhostrate  dsthostserrorrate  \
# ...

# %%
test_data.head()
# Out:
#    duration protocoltype  service flag  srcbytes  dstbytes  land  \
# 0         0          tcp      mtp  REJ         0         0     0
# 1         0          tcp     http   SF       199      1721     0
# 2         0          tcp  discard   S0         0         0     0
# 3         0          tcp   telnet   S0         0         0     0
# 4         0          tcp     exec   S0         0         0     0
#
#    wrongfragment  urgent  hot  ...  dsthostsrvcount  dsthostsamesrvrate  \
# 0              0       0    0  ...                7                0.03
# 1              0       0    0  ...              255                1.00
# 2              0       0    0  ...               14                0.05
# 3              0       0    0  ...                2                0.01
# 4              0       0    0  ...               16                0.06
#
#    dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# ...

# %%
Sample_Submission.head()
# Out:
#     attack
# 0   normal
# 1   normal
# 2   normal
# 3  neptune
# 4  neptune

# %%
train_data.head()
# Out:
#    duration protocoltype      service flag  srcbytes  dstbytes  land  \
# 0         0          tcp  netbios_dgm  REJ         0         0     0
# 1         0          tcp         smtp   SF      1239       400     0
# 2         0          tcp         http   SF       222       945     0
# 3         0          tcp         http   SF       235      1380     0
# 4         0          tcp    uucp_path  REJ         0         0     0
#
#    wrongfragment  urgent  hot  ...  dsthostsamesrvrate  dsthostdiffsrvrate  \
# 0              0       0    0  ...                0.06                0.06
# 1              0       0    0  ...                0.45                0.04
# 2              0       0    0  ...                1.00                0.00
# 3              0       0    0  ...                1.00                0.00
# 4              0       0    0  ...                0.01                0.08
#
#    dsthostsamesrcportrate  dsthostsrvdiffhostrate  dsthostserrorrate  \
# ...

# %%
train_data.shape
# Out:
# (86845, 43)

# %%
train_data.describe()
# Out:
#            duration      srcbytes      dstbytes          land  wrongfragment  \
# count  86845.000000  8.684500e+04  8.684500e+04  86845.000000        86845.0
# mean     104.166872  8.455707e+03  2.732095e+03      0.000046            0.0
# std     1038.273538  3.582141e+05  5.543041e+04      0.006787            0.0
# min        0.000000  0.000000e+00  0.000000e+00      0.000000            0.0
# 25%        0.000000  0.000000e+00  0.000000e+00      0.000000            0.0
# 50%        0.000000  4.600000e+01  4.400000e+01      0.000000            0.0
# 75%        0.000000  2.720000e+02  7.680000e+02      0.000000            0.0
# max    40504.000000  8.958152e+07  7.028652e+06      1.000000            0.0
#
#              urgent           hot  numfailedlogins      loggedin  \
# count  86845.000000  86845.000000     86845.000000  86845.000000
# mean       0.000035      0.144971         0.000771      0.441142
# std        0.007588      1.837958         0.037009      0.496527
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86845 entries, 0 to 86844
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   duration                86845 non-null  int64
#  1   protocoltype            86845 non-null  object
#  2   service                 86845 non-null  object
#  3   flag                    86845 non-null  object
#  4   srcbytes                86845 non-null  int64
#  5   dstbytes                86845 non-null  int64
#  6   land                    86845 non-null  int64
#  7   wrongfragment           86845 non-null  int64
#  8   urgent                  86845 non-null  int64
#  9   hot                     86845 non-null  int64
#  10  numfailedlogins         86845 non-null  int64
#  11  loggedin                86845 non-null  int64
#  12  numcompromised          86845 non-null  int64
#  13  rootshell               86845 non-null  int64
# ...

# %%
X=train_data.drop(['attack'],axis=1)

# %%
X.head()
# Out:
#    duration protocoltype      service flag  srcbytes  dstbytes  land  \
# 0         0          tcp  netbios_dgm  REJ         0         0     0
# 1         0          tcp         smtp   SF      1239       400     0
# 2         0          tcp         http   SF       222       945     0
# 3         0          tcp         http   SF       235      1380     0
# 4         0          tcp    uucp_path  REJ         0         0     0
#
#    wrongfragment  urgent  hot  ...  dsthostsrvcount  dsthostsamesrvrate  \
# 0              0       0    0  ...               15                0.06
# 1              0       0    0  ...              116                0.45
# 2              0       0    0  ...              255                1.00
# 3              0       0    0  ...              255                1.00
# 4              0       0    0  ...                3                0.01
#
#    dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# ...

# %%
y=train_data['attack']

# %%
y
# Out:
# 0        neptune
# 1         normal
# 2         normal
# 3         normal
# 4        neptune
#           ...
# 86840     normal
# 86841     normal
# 86842     normal
# 86843     normal
# 86844     normal
# Name: attack, Length: 86845, dtype: object

# %%
y.value_counts()
# Out:
# attack
# normal     53847
# neptune    32998
# Name: count, dtype: int64

# %%
train_data['attack'].value_counts()
# Out:
# attack
# normal     53847
# neptune    32998
# Name: count, dtype: int64

# %%
X.head()
# Out:
#    duration protocoltype      service flag  srcbytes  dstbytes  land  \
# 0         0          tcp  netbios_dgm  REJ         0         0     0
# 1         0          tcp         smtp   SF      1239       400     0
# 2         0          tcp         http   SF       222       945     0
# 3         0          tcp         http   SF       235      1380     0
# 4         0          tcp    uucp_path  REJ         0         0     0
#
#    wrongfragment  urgent  hot  ...  dsthostsrvcount  dsthostsamesrvrate  \
# 0              0       0    0  ...               15                0.06
# 1              0       0    0  ...              116                0.45
# 2              0       0    0  ...              255                1.00
# 3              0       0    0  ...              255                1.00
# 4              0       0    0  ...                3                0.01
#
#    dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86845 entries, 0 to 86844
# Data columns (total 42 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   duration                86845 non-null  int64
#  1   protocoltype            86845 non-null  object
#  2   service                 86845 non-null  object
#  3   flag                    86845 non-null  object
#  4   srcbytes                86845 non-null  int64
#  5   dstbytes                86845 non-null  int64
#  6   land                    86845 non-null  int64
#  7   wrongfragment           86845 non-null  int64
#  8   urgent                  86845 non-null  int64
#  9   hot                     86845 non-null  int64
#  10  numfailedlogins         86845 non-null  int64
#  11  loggedin                86845 non-null  int64
#  12  numcompromised          86845 non-null  int64
#  13  rootshell               86845 non-null  int64
# ...

# %%
X['protocoltype'].value_counts()
# Out:
# protocoltype
# tcp     75876
# udp      9929
# icmp     1040
# Name: count, dtype: int64

# %%
X['service'].value_counts()
# Out:
# service
# http        31505
# private     12859
# domain_u     7196
# smtp         5806
# ftp_data     4929
#             ...
# printer        46
# urh_i           9
# red_i           6
# tim_i           4
# tftp_u          3
# Name: count, Length: 65, dtype: int64

# %%
X['flag'].value_counts()
# Out:
# flag
# SF      50672
# S0      27773
# REJ      6721
# RSTO     1127
# S1        294
# RSTR      106
# S2        103
# S3         38
# OTH        10
# SH          1
# Name: count, dtype: int64

# %%
X.shape
# Out:
# (86845, 42)

# %%
from sklearn.preprocessing import LabelEncoder , StandardScaler

categorical_cols = ['protocoltype', 'service', 'flag']
label_encoders = {col: LabelEncoder() for col in categorical_cols}
for col in categorical_cols:
    train_data[col] = label_encoders[col].fit_transform(train_data[col])
    test_data[col] = label_encoders[col].transform(test_data[col])

# %%
train_data
# Out:
#        duration  protocoltype  service  flag  srcbytes  dstbytes  land  \
# 0             0             1       33     1         0         0     0
# 1             0             1       49     8      1239       400     0
# 2             0             1       22     8       222       945     0
# 3             0             1       22     8       235      1380     0
# 4             0             1       62     1         0         0     0
# ...         ...           ...      ...   ...       ...       ...   ...
# 86840         0             1       22     8       216       674     0
# 86841         0             1       22     8       368      1725     0
# 86842        28             1       18     8      1483      4152     0
# 86843         0             1       49     8      1679       385     0
# 86844     11343             1       55     8      3396     16694     0
#
#        wrongfragment  urgent  hot  ...  dsthostsamesrvrate  \
# ...

# %%
train_data['protocoltype'].value_counts()
# Out:
# protocoltype
# 1    75876
# 2     9929
# 0     1040
# Name: count, dtype: int64

# %%
train_data['service'].value_counts()
# Out:
# service
# 22    31505
# 44    12859
# 11     7196
# 49     5806
# 19     4929
#       ...
# 43       46
# 59        9
# 45        6
# 57        4
# 56        3
# Name: count, Length: 65, dtype: int64

# %%
train_data['flag'].value_counts()
# Out:
# flag
# 8    50672
# 4    27773
# 1     6721
# 2     1127
# 5      294
# 3      106
# 6      103
# 7       38
# 0       10
# 9        1
# Name: count, dtype: int64

# %%
X=train_data.drop(['attack'],axis=1)
y=train_data['attack']
y=y.replace({'normal':0,'neptune':1})

# %%
X.head()
# Out:
#    duration  protocoltype  service  flag  srcbytes  dstbytes  land  \
# 0         0             1       33     1         0         0     0
# 1         0             1       49     8      1239       400     0
# 2         0             1       22     8       222       945     0
# 3         0             1       22     8       235      1380     0
# 4         0             1       62     1         0         0     0
#
#    wrongfragment  urgent  hot  ...  dsthostsrvcount  dsthostsamesrvrate  \
# 0              0       0    0  ...               15                0.06
# 1              0       0    0  ...              116                0.45
# 2              0       0    0  ...              255                1.00
# 3              0       0    0  ...              255                1.00
# 4              0       0    0  ...                3                0.01
#
#    dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# ...

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: attack, dtype: int64

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86845 entries, 0 to 86844
# Data columns (total 42 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   duration                86845 non-null  int64
#  1   protocoltype            86845 non-null  int32
#  2   service                 86845 non-null  int32
#  3   flag                    86845 non-null  int32
#  4   srcbytes                86845 non-null  int64
#  5   dstbytes                86845 non-null  int64
#  6   land                    86845 non-null  int64
#  7   wrongfragment           86845 non-null  int64
#  8   urgent                  86845 non-null  int64
#  9   hot                     86845 non-null  int64
#  10  numfailedlogins         86845 non-null  int64
#  11  loggedin                86845 non-null  int64
#  12  numcompromised          86845 non-null  int64
#  13  rootshell               86845 non-null  int64
# ...

# %%
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
test_data_scaled = scaler.transform(test_data)

# %%
X_scaled
# Out:
# array([[-0.10032758, -0.30074572,  0.30278717, ...,  3.20974994,
#          3.22954213,  0.66094499],
#        [-0.10032758, -0.30074572,  1.38396873, ..., -0.25601019,
#         -0.32348435, -1.44962509],
#        [-0.10032758, -0.30074572, -0.44052515, ..., -0.32673999,
#         -0.32348435,  0.66094499],
#        ...,
#        [-0.07335958, -0.30074572, -0.71082054, ..., -0.32673999,
#         -0.32348435, -0.04257837],
#        [-0.10032758, -0.30074572,  1.38396873, ..., -0.29137509,
#         -0.32348435, -1.44962509],
#        [10.82460202, -0.30074572,  1.78941181, ..., -0.32673999,
#         -0.32348435, -1.44962509]])

# %%
test_data_scaled
# Out:
# array([[-0.10032758, -0.30074572,  0.16763948, ...,  3.20974994,
#          3.22954213, -0.04257837],
#        [-0.10032758, -0.30074572, -0.44052515, ..., -0.32673999,
#         -0.32348435,  0.66094499],
#        [-0.10032758, -0.30074572, -1.31898517, ..., -0.32673999,
#         -0.32348435, -1.44962509],
#        ...,
#        [-0.10032758, -0.30074572, -0.30537746, ..., -0.32673999,
#         -0.32348435, -0.04257837],
#        [-0.10032758, -0.30074572, -0.64324669, ..., -0.32673999,
#         -0.32348435,  0.66094499],
#        [-0.10032758, -0.30074572,  1.04609949, ..., -0.32673999,
#         -0.32348435,  0.66094499]])

# %%
x_train,x_val,y_train,y_val = train_test_split(X_scaled,y,test_size=0.3,random_state=42)

# %%
x_train.size
# Out:
# 2553222

# %%
y_train
# Out:
# 78954    1
# 71202    0
# 49399    0
# 17271    1
# 65632    0
#         ..
# 6265     0
# 54886    0
# 76820    1
# 860      0
# 15795    1
# Name: attack, Length: 60791, dtype: int64

# %%
y_val
# Out:
# 86586    1
# 29760    0
# 45563    1
# 6478     0
# 22782    0
#         ..
# 15614    0
# 54541    0
# 80328    0
# 14670    1
# 7790     1
# Name: attack, Length: 26054, dtype: int64

# %%
x_val
# Out:
# array([[-0.10032758, -0.30074572, -0.91354208, ..., -0.32673999,
#         -0.32348435, -1.44962509],
#        [-0.10032758, -0.30074572, -0.44052515, ..., -0.32673999,
#         -0.32348435,  0.66094499],
#        [-0.10032758, -0.30074572,  1.78941181, ..., -0.32673999,
#         -0.32348435, -1.44962509],
#        ...,
#        [-0.10032758,  2.63752204,  1.04609949, ..., -0.32673999,
#         -0.32348435, -2.15314845],
#        [-0.10032758, -0.30074572,  1.04609949, ..., -0.32673999,
#         -0.32348435,  0.66094499],
#        [-0.10032758, -0.30074572,  2.1948549 , ..., -0.32673999,
#         -0.32348435, -0.74610173]])

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(max_iter=1000 , random_state=42)
log_reg.fit(x_train,y_train)
y_pred=log_reg.predict(x_val)

# %%
from sklearn.metrics import f1_score
f1_score(y_pred,y_val)
# Out:
# 0.999848568976831

# %%
x_val
# Out:
# array([[-0.10032758, -0.30074572, -0.91354208, ..., -0.32673999,
#         -0.32348435, -1.44962509],
#        [-0.10032758, -0.30074572, -0.44052515, ..., -0.32673999,
#         -0.32348435,  0.66094499],
#        [-0.10032758, -0.30074572,  1.78941181, ..., -0.32673999,
#         -0.32348435, -1.44962509],
#        ...,
#        [-0.10032758,  2.63752204,  1.04609949, ..., -0.32673999,
#         -0.32348435, -2.15314845],
#        [-0.10032758, -0.30074572,  1.04609949, ..., -0.32673999,
#         -0.32348435,  0.66094499],
#        [-0.10032758, -0.30074572,  2.1948549 , ..., -0.32673999,
#         -0.32348435, -0.74610173]])

# %%
from sklearn.tree import DecisionTreeClassifier

decision_tree = DecisionTreeClassifier(random_state=42)
decision_tree.fit(x_train,y_train)
y_pred=decision_tree.predict(x_val)

# %%
from sklearn.metrics import f1_score
f1_score(y_pred,y_val)
# Out:
# 0.9994952554007672

# %%
from sklearn.ensemble import RandomForestClassifier

random_clf=RandomForestClassifier(random_state=30)
random_clf.fit(x_train,y_train)
y_pred=random_clf.predict(x_val)

# %%
f1_score(y_pred,y_val)
# Out:
# 0.9999495280876192

# %%
from sklearn.svm import SVC

svc=SVC(random_state=42)
svc.fit(x_train,y_train)

y_pred= svc.predict(x_val)

# %%
f1_score(y_pred,y_val)
# Out:
# 0.9999495229922769

# %%
COUNTER =0
for i in y_pred:
    print(i)
    COUNTER=COUNTER+1
    if COUNTER == 5:
        break
# Out:
# 1
# 0
# 1
# 0
# 0

# %%
y_val
# Out:
# 86586    1
# 29760    0
# 45563    1
# 6478     0
# 22782    0
#         ..
# 15614    0
# 54541    0
# 80328    0
# 14670    1
# 7790     1
# Name: attack, Length: 26054, dtype: int64

# %%
y_final_submit = svc.predict(test_data_scaled)

# %%
y_final_submit
# Out:
# array([1, 0, 1, ..., 1, 0, 1], dtype=int64)

# %%
Sample_Submission
# Out:
#         attack
# 0       normal
# 1       normal
# 2       normal
# 3      neptune
# 4      neptune
# ...        ...
# 21707   normal
# 21708  neptune
# 21709   normal
# 21710   normal
# 21711   normal
#
# [21712 rows x 1 columns]

# %%
final_sub=pd.DataFrame(y_final_submit,columns=['attack'])

# %%
final_sub
# Out:
#        attack
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1
# ...       ...
# 21707       0
# 21708       0
# 21709       1
# 21710       0
# 21711       1
#
# [21712 rows x 1 columns]

# %%
final_sub.to_csv(r"C:\Users\Ajay Mulgir\portfolio project\Portfolio\GUWAHATI\WEEK5\week5_submission.csv")
