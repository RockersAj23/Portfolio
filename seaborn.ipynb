# %%
from matplotlib import pyplot as plt

# %%
x=[10,20,30,40]
y=[0,15,10,25]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
#  # Seaborn

# %% [markdown]
# doing same thing by seaborn

# %%
import seaborn as sns

# %%
sns.set()

# %%
plt.plot(x,y)
plt.show()
#seaborn is just at the top of the matplot lov , its enhancing matplot but the code is same as 
#usual

# %%
sns.set_style('white')

# %%
plt.plot(x,y)

# %% [markdown]
# checking versions \n
# seaborn just updates rc parameters of the matplotlib , rc stands for run command (which are default parameters)

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.8.0'

# %%
sns.__version__
# Out:
# '0.12.2'

# %% [markdown]
# trying to integrate seaborn with pandas

# %%
cars=sns.load_dataset('mpg')
# mpg ek chota dataset aahe je online import kelay.
#jast pareshan whay chi garaj nahi

# %%
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
cars.dropna(inplace=True)
cars.shape
# Out:
# (392, 9)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df=pd.concat([cars,new_row],ignore_index=True)
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
new_row=pd.DataFrame([{'mpg':25,'cylinders':4,'displacement':25000 ,'horsepower':307,'weight':200,'acceleration':18,'model_year':85,'origin':'India','name':'Tiago Tata'}])

# %%
sns.relplot(x='model_year',y='mpg',col='origin',hue='cylinders',
            data=df)

# %% [markdown]
# # 2nd lec (KDE PLOT)
